# %%
import requests
import json
import time
import alpaca_trade_api as tradeapi


api_key = 'PKWETDDV2U3YAH5VOMX4'
api_secret = 'e6LbSunfIjt3fTdDGBm2demTX7lOYYTvKmGECRlX'
base_url = 'https://paper-api.alpaca.markets'
api = tradeapi.REST(api_key, api_secret, base_url, api_version='v2')



# define Mean reversion function
def meanReversionStrategy(prices):

    i = 0
    buy = 0
    sell = 0
    total_profit = 0
    first_buy = 0

    print('\n-----------------Mean Reversion Strategy for', ticker,'-----------------')

    # for loop runs strategy on each line of a ticker
    for price in prices:
        if i >= 5:
            avg = (prices[i-1] + prices[i-2] + prices[i-3] + prices[i-4] + prices[i-5]) / 5

            if price < avg * .98 and buy == 0 and sell == 0: #buy logic
                #print('Buying', ticker, 'at: ', round(price, 2))
                buy = price

                if i == len(prices) - 1:
                    print("Buy this today")

                    try:
                        # Place buy order
                        order = api.submit_order(
                            symbol=ticker,
                            qty=100,
                            side='buy',
                            type='limit',
                            time_in_force='gtc',
                            limit_price=price
                        )
                        print(order)
                    except:
                        print("restrictions preventing order")

                if first_buy == 0:  #if statement to store first buy
                    first_buy = price


            elif price > avg * 1.02 and buy != 0 and sell == 0:    #sell logic
                #print("Selling", ticker,"at: ", round(price, 2))
                profit = price - buy
                #print("Profit: ", round(profit, 2), '\n')
                total_profit += profit
                buy = 0

                if i == len(prices) - 1:
                    print("Sell this today")

                    try:
                        # Place sell order
                        order = api.submit_order(
                            symbol=ticker,
                            qty=100,
                            side='sell',
                            type='limit',
                            time_in_force='gtc',
                            limit_price=price
                        )
                        print(order)
                    except:
                        print("restrictions preventing order")

            elif price > avg * 1.02 and buy == 0 and sell == 0:
                sell = price
                #print("Selling", ticker, "at: ", round(price, 2))

                if i == len(prices) - 1:
                    print("Sell this today")

                    try:
                        # Place sell order
                        order = api.submit_order(
                            symbol=ticker,
                            qty=100,
                            side='sell',
                            type='limit',
                            time_in_force='gtc',
                            limit_price=price
                        )
                        print(order)
                    except:
                        print("restrictions preventing order")

            elif price < avg * 98 and buy == 0 and sell != 0:
                buy = price
                #print('Buying', ticker, 'at: ', round(price, 2))
                profit = sell - buy
                #print("Profit: ", round(profit, 2), '\n')
                total_profit += profit
                sell = 0
                buy = 0

                if i == len(prices) - 1:
                    print("Buy this today")

                    try:
                        # Place buy order
                        order = api.submit_order(
                            symbol=ticker,
                            qty=100,
                            side='buy',
                            type='limit',
                            time_in_force='gtc',
                            limit_price=price
                        )
                        print(order)
                    except:
                        print("restrictions preventing order")

            else:
                pass

        i += 1

    returns = (total_profit / first_buy) * 100
    print("Total Profit for ", ticker, ": ", round(total_profit, 2), "\nTotal Return for ", ticker, ": ", round(returns, 2), sep = '')
    return total_profit, returns

# define SMA function
def simpleMovingAverageStrategy(prices):

    i = 0
    buy = 0
    sell = 0
    total_profit = 0
    first_buy = 0

    print('\n-----------------Simple Moving Average Strategy for', ticker,'-----------------')

    for price in prices:
        if i >= 5:
            avg = (prices[i-1] + prices[i-2] + prices[i-3] + prices[i-4] + prices[i-5]) / 5

            if price > avg and buy == 0 and sell == 0:
                #print('Buying', ticker, 'at: ', round(price, 2))
                buy = price

                if i == len(prices) - 1:
                    print("Buy this today")


                    try:
                        # Place buy order
                        order = api.submit_order(
                            symbol=ticker,
                            qty=100,
                            side='buy',
                            type='limit',
                            time_in_force='gtc',
                            limit_price=price
                        )
                        print(order)
                    except:
                        print("restrictions preventing order")

                if first_buy == 0:
                    first_buy = price

            elif price < avg and buy != 0 and sell == 0:
                #print("Selling", ticker,"at: ", round(price, 2))
                profit = price - buy
                #print("Profit: ", round(profit, 2), '\n')
                total_profit += profit
                buy = 0

                if i == len(prices) - 1:
                    print("Sell this today")

                    try:
                        # Place sell order
                        order = api.submit_order(
                            symbol=ticker,
                            qty=100,
                            side='sell',
                            type='limit',
                            time_in_force='gtc',
                            limit_price=price
                        )
                        print(order)
                    except:
                        print("restrictions preventing order")

            elif price < avg and buy == 0 and sell == 0:
                sell = price
                #print("Selling", ticker, "at: ", round(price, 2))

                if i == len(prices) - 1:
                    print("Sell this today")

                    try:
                        # Place sell order
                        order = api.submit_order(
                            symbol=ticker,
                            qty=100,
                            side='sell',
                            type='limit',
                            time_in_force='gtc',
                            limit_price=price
                        )
                        print(order)
                    except:
                        print("restrictions preventing order")

            elif price > avg and buy == 0 and sell != 0:
                buy = price
                #print('Buying', ticker, 'at: ', round(price))
                profit = sell - buy
                #print("Profit: ", round(profit, 2), '\n')
                total_profit += profit
                sell = 0
                buy = 0

                if i == len(prices) - 1:
                    print("Buy this today")

                    try:
                        # Place buy order
                        order = api.submit_order(
                            symbol=ticker,
                            qty=100,
                            side='buy',
                            type='limit',
                            time_in_force='gtc',
                            limit_price=price
                        )
                        print(order)
                    except:
                        print("restrictions preventing order")

            else:
                pass

        i += 1

    returns = (total_profit / first_buy) * 100
    print("Total Profit for ", ticker, ": ", round(total_profit, 2), "\nTotal Return for ", ticker, ": ", round(returns, 2), sep = '')
    return total_profit, returns

def BollingerBandsStrategy(prices):

    i = 0
    buy = 0
    sell = 0
    total_profit = 0
    first_buy = 0

    print('\n----------------- Bollinger Bands Strategy for', ticker,'-----------------')

    # for loop runs strategy on each line of a ticker
    for price in prices:
        if i >= 5:
            avg = (prices[i-1] + prices[i-2] + prices[i-3] + prices[i-4] + prices[i-5]) / 5

            if price > avg * 1.05 and buy == 0 and sell == 0: #buy logic
                #print('Buying', ticker, 'at: ', round(price, 2))
                buy = price

                if i == len(prices) - 1:
                    print("Buy this today")

                    try:
                        # Place buy order
                        order = api.submit_order(
                            symbol=ticker,
                            qty=100,
                            side='buy',
                            type='limit',
                            time_in_force='gtc',
                            limit_price=price
                        )
                        print(order)
                    except:
                        print("restrictions preventing order")

                if first_buy == 0:  #if statement to store first buy
                    first_buy = price

            elif price < avg * .95 and buy != 0 and sell == 0:    #sell logic
                #print("Selling", ticker,"at: ", round(price, 2))
                profit = price - buy
                #print("Profit: ", round(profit, 2), '\n')
                total_profit += profit
                buy = 0

                if i == len(prices) - 1:
                    print("Sell this today")

                    try:
                        # Place sell order
                        order = api.submit_order(
                            symbol=ticker,
                            qty=100,
                            side='sell',
                            type='limit',
                            time_in_force='gtc',
                            limit_price=price
                        )
                        print(order)
                    except:
                        print("restrictions preventing order")

            elif price < avg * .95 and buy == 0 and sell == 0:
                sell = price
                #print("Selling", ticker, "at: ", round(price, 2))

                if i == len(prices) - 1:
                    print("Sell this today")

                    try:
                        # Place sell order
                        order = api.submit_order(
                            symbol=ticker,
                            qty=100,
                            side='sell',
                            type='limit',
                            time_in_force='gtc',
                            limit_price=price
                        )
                        print(order)
                    except:
                        print("restrictions preventing order")

            elif price > avg * 1.05 and buy == 0 and sell != 0:
                buy = price
                #print('Buying', ticker, 'at: ', round(price, 2))
                profit = sell - buy
                #print("Profit: ", round(profit, 2), '\n')
                total_profit += profit
                sell = 0
                buy = 0

                if i == len(prices) - 1:
                    print("Buy this today")

                    try:
                        # Place buy order
                        order = api.submit_order(
                            symbol=ticker,
                            qty=100,
                            side='buy',
                            type='limit',
                            time_in_force='gtc',
                            limit_price=price
                        )
                        print(order)
                    except:
                        print("restrictions preventing order")

            else:
                pass

        i += 1

    returns = (total_profit / first_buy) * 100
    print("Total Profit for ", ticker, ": ", round(total_profit, 2), "\nTotal Return for ", ticker, ": ", round(returns, 2), sep = '')
    return total_profit, returns




tickers = ['AAPL', 'ADBE', 'AMZN', 'BA', 'CSCO', 'GOOG', 'META', 'MSFT', 'TSLA', 'WMT']
results = {}



HP = 0
HR = 0
results["Best Ticker"] = ""
results["Strategy"] = ""
results["Profit"] = ""
results["Return"] = ""

for ticker in tickers:

    url = "https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol="+ticker+"&outputsize=full&apikey=NG9C9EPVYBMQT0C8"
    req = requests.get(url)
    time.sleep(12)


    req_dct = json.loads(req.text)

    time_key = "Time Series (Daily)"
    price_key = "4. close"

    csv_fil = open("data"+ ticker +  ".csv", "w")

    lst = []


    for date in req_dct[time_key]:
        lst.append(date + "," + req_dct[time_key][date][price_key])

    lst.reverse()

    for l in lst:
        csv_fil.write(l + '\n')

    csv_fil.close()


    prices = []


    for line in lst:
        prices.append(float(line.split(",")[1]))

    total_profit, returns = meanReversionStrategy(prices) #save to dictionary
    results[ticker + ' mean reversion profit: '] = '${:,.2f}'.format(total_profit)
    results[ticker + ' mean reversion returns: '] = '{:,.2f}%'.format(returns)

    if returns > HR and total_profit > HP:

        HR = returns
        HP = total_profit
        results["Profit"] = '${:,.2f}'.format(total_profit)
        results["Return"] = '{:,.2f}%'.format(returns)
        results["Best Ticker"] = ticker
        results["Strategy"] = "Mean Reversion"

    total_profit, returns = simpleMovingAverageStrategy(prices)
    results[ticker + ' moving average profit : '] = '${:,.2f}'.format(total_profit)
    results[ticker + ' moving average returns : '] = '{:,.2f}%'.format(returns)

    if returns > HR and total_profit > HP:

        HR = returns
        HP = total_profit
        results["Profit"] = '${:,.2f}'.format(total_profit)
        results["Return"] = '{:,.2f}%'.format(returns)
        results["Best Ticker"] = ticker
        results["Strategy"] = "Moving Average"

    total_profit, returns = BollingerBandsStrategy(prices)
    results[ticker + ' bollinger bands profit : '] = '${:,.2f}'.format(total_profit)
    results[ticker + ' bollinger bands returns : '] = '{:,.2f}%'.format(returns)

    if returns > HR and total_profit > HP:

        HR = returns
        HP = total_profit
        results["Profit"] = '${:,.2f}'.format(total_profit)
        results["Return"] = '{:,.2f}%'.format(returns)
        results["Best Ticker"] = ticker
        results["Strategy"] = "Bollinger Bands"

def save_results(results):  #save as a json file
    json.dump(results, open('results.json', 'w'), indent = 4)

save_results(results)


input("press enter to end: ")
# Out:
# -----------------Mean Reversion Strategy for AAPL -----------------
# Total Profit for AAPL: -233.97
# Total Return for AAPL: -261.59
#
# -----------------Simple Moving Average Strategy for AAPL -----------------
# Total Profit for AAPL: 43.32
# Total Return for AAPL: 44.95
#
# ----------------- Bollinger Bands Strategy for AAPL -----------------
# Total Profit for AAPL: -878.2
# Total Return for AAPL: -911.28
#
# -----------------Mean Reversion Strategy for ADBE -----------------
# Total Profit for ADBE: 546.95
# Total Return for ADBE: 741.02
#
# -----------------Simple Moving Average Strategy for ADBE -----------------
# Sell this today
# restrictions preventing order
# Total Profit for ADBE: -286.51
# Total Return for ADBE: -401.38
#
# ----------------- Bollinger Bands Strategy for ADBE -----------------
# Total Profit for ADBE: -283.84
# Total Return for ADBE: -383.57
#
# -----------------Mean Reversion Strategy for AMZN -----------------
# Buy this today
# ...
